# %%
import pandas as pd 

df=pd.read_csv('data.csv')

# %%
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df.dropna(subset=['umpire3','winner','player_of_match'],inplace=True)
df
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Know we will segregate categorical and Numerical Columns

# %%
categorical_columns=df.columns[df.dtypes=='object']
numerical_columns=df.columns[df.dtypes!='object']
print(f"this is are our numerical columns:{numerical_columns}")
print(f"this is are our categorical colummns:{categorical_columns}")
# Out:
# this is are our numerical columns:Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='str')
# this is are our categorical colummns:Index([], dtype='str')
